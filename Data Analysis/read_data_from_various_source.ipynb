# %%
# Need to get read the json in the format of the data frame 
import pandas as pd 
from io import StringIO
Data = '{"employee_name" : "Anand" , "email" : "anand@gmail.com" , "Job_Title" : [{"Title 1" : "Team Lead" , "Title 2" : "AI/ML ENgineer"}]}'
df = pd.read_json(StringIO(Data))
df.head()
# Out:
#   employee_name            email  \
# 0         Anand  anand@gmail.com
#
#                                            Job_Title
# 0  {'Title 1': 'Team Lead', 'Title 2': 'AI/ML ENg...

# %%
# in order to convert the data to json 
df.to_json()
# Out:
# '{"employee_name":{"0":"Anand"},"email":{"0":"anand@gmail.com"},"Job_Title":{"0":{"Title 1":"Team Lead","Title 2":"AI\\/ML ENgineer"}}}'

# %%
# alternate options 
df.to_json(orient='records')
# Out:
# '[{"employee_name":"Anand","email":"anand@gmail.com","Job_Title":{"Title 1":"Team Lead","Title 2":"AI\\/ML ENgineer"}}]'

# %%
# !pip install html5lib
# !pip install beautifulsoup4

# %%
# need to get the data from a HTML web page 
url = "https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/"
df = pd.read_html(url , match='State' , header=0)

# %%
df[0]
# Out:
#                                Bank Name               City         State  \
# 0                   Pulaski Savings Bank            Chicago      Illinois
# 1     The First National Bank of Lindsay            Lindsay      Oklahoma
# 2  Republic First Bank dba Republic Bank       Philadelphia  Pennsylvania
# 3                          Citizens Bank           Sac City          Iowa
# 4               Heartland Tri-State Bank            Elkhart        Kansas
# 5                    First Republic Bank      San Francisco    California
# 6                         Signature Bank           New York      New York
# 7                    Silicon Valley Bank        Santa Clara    California
# 8                      Almena State Bank             Almena        Kansas
# 9             First City Bank of Florida  Fort Walton Beach       Florida
#
#     Cert                 Aquiring Institution      Closing Date  \
# 0  28611                      Millennium Bank  January 17, 2025
# ...

# %%
url = "https://en.wikipedia.org//wiki/Mobile_country_code"
data_df = pd.read_html(url , match="Country" , header=0)

# %%
data_df[0]
# Out:
#      Mobile country code                                    Country ISO 3166  \
# 0                    289                                 A Abkhazia    GE-AB
# 1                    412                                Afghanistan       AF
# 2                    276                                    Albania       AL
# 3                    603                                    Algeria       DZ
# 4                    544  American Samoa (United States of America)       AS
# ..                   ...                                        ...      ...
# 247                  452                                    Vietnam       VN
# 248                  543                        W Wallis and Futuna       WF
# 249                  421                                    Y Yemen       YE
# 250                  645                                   Z Zambia       ZM
# 251                  648                                   Zimbabwe       ZW
#
# ...

# %%
scrap_url = "https://en.wikipedia.org/wiki/Information_technology_in_India"
tables = pd.read_html(scrap_url , match='IT Services Company name' , header=0)

# %%
tables[0]
# Out:
#    Rank   IT Services Company name  \
# 0     1  Tata Consultancy Services
# 1     2                    Infosys
# 2     3                      Wipro
# 3     4           HCL Technologies
# 4     5                LTIMindtree
# 5     6              Tech Mahindra
#
#    Market capitalization in 2022(US$ Billion)  \
# 0                                      200.00
# 1                                      100.00
# 2                                       50.00
# 3                                       36.67
# 4                                       20.86
# 5                                       12.65
#
#    Market capitalization in 2022(₹ Cr)
# 0                           1463372.44
# 1                            734140.78
# 2                            317428.00
# 3                            318061.00
# 4                            133592.40
# 5                            133592.40
